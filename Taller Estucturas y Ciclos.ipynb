# %%
x = 0
x = float(input("Registre la calificación del estudiante..."))
if (x < 3):
    print ("El estudiante pierde")
elif (x > 3): 
    print ("El estudiante gana")
else:
    print ("El estudiante debe repetir la prueba")
# Out:
# Registre la calificación del estudiante...3
# El estudiante debe repetir la prueba

# %%
x = 0
y = 1
z = 11
while (y < z):
    x = float(input("Registre la calificación del estudiante " + str(y)+ "..."))
    if (x < 3):
        print ("El estudiante " + str(y)+ " pierde")
    elif (x > 3): 
        print ("El estudiante " + str(y)+ " gana")
    else:
        print ("El estudiante "+ str(y)+ " debe repetir la prueba")
    y+=1

print ("ha registrado las calificaciones de "+ str(y-1)+ " estudiantes")

# %%
Logitud = 0
Ancho = 0
Altura = 0
ABase = 0
Volumen = 0
Longitud = float(input("Ingrese la longitud del prisma "))
Ancho = float(input("Ingrese ancho del prisma "))
Altura = float(input("Ingrese la altura del prisma "))

# Area Base * Altura
# Area Base = (Longitud * Ancho) / 2
#Volumen = Area base * Altura

ABase= ((Longitud * Ancho)/2)
Volumen = (ABase * Altura)

print ("El volumen del prisma es "+str(Volumen))

# %%
#Serie Fibonacii

x=0
y=1
z=0
print (str (x))
print (str (y))
while (z <= 100):
    z= x+y
    y = z
    x = y
    print (str (z))
# Out:
# 0
# 1
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
