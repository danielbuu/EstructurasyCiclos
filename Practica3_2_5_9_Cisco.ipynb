# %%
y = 5
x = 5
if (x > y):
  print ("x mayor que y")
elif (x < y):
  print ("y mayor que x")
else:
    print ("x es igual a y")
# Out:
# x es igual a y

# %%
import random, math
random.seed()
x = math.floor(random.random()*1000)+1
z = 0
b = 0
while x != z:
 b=b+1
 z = int(input("Adivina mi número entre 1 y 1000: "))
 if z < x:
      print("Mayor!")
 if z > x:
      print("Menor!")
print("Correcto!, adivinaste después de " + str(b) + " intentos.")
# Out:
# Adivina mi número entre 1 y 1000: 1
# Mayor!
# Adivina mi número entre 1 y 1000: 10
# Mayor!
# Adivina mi número entre 1 y 1000: 100
# Mayor!
# Adivina mi número entre 1 y 1000: 200
# Mayor!
# Adivina mi número entre 1 y 1000: 300
# Mayor!
# Adivina mi número entre 1 y 1000: 500
# Menor!
# Adivina mi número entre 1 y 1000: 800
# Menor!
# Adivina mi número entre 1 y 1000: 600
# Menor!
# Adivina mi número entre 1 y 1000: 450
# Menor!
# Adivina mi número entre 1 y 1000: 400
# Mayor!
# Adivina mi número entre 1 y 1000: 430
# Menor!
# Adivina mi número entre 1 y 1000: 405
# Mayor!
# Adivina mi número entre 1 y 1000: 410
# Mayor!
# Adivina mi número entre 1 y 1000: 419
# Mayor!
# Adivina mi número entre 1 y 1000: 425
# Menor!
# Adivina mi número entre 1 y 1000: 422
# Mayor!
# Adivina mi número entre 1 y 1000: 424
# Correcto!, adivinaste después de 17 intentos.

# %%
x = 0
x = int(input("Registre la calificación del estudiante..."))
if (x < 3):
    print ("El estudiante pierde")
    else 
    print ("El estudiante gana")
